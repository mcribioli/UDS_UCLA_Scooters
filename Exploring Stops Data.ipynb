# %%
import pandas as pd
import geopandas as gpd
import json
from pandas import json_normalize

# %%
Stops = pd.read_csv('Data/Stop 1 2023-05-18.csv', index_col=0)
Stops.head()
# Out:
#   global_route_id                                        itineraries  \
# 0       BBB:14413  [{'branch_code': '', 'direction_headsign': 'UC...
# 1       BBB:82618  [{'branch_code': '', 'direction_headsign': 'UC...
# 2       BBB:69580  [{'branch_code': '', 'direction_headsign': 'UC...
# 0       BBB:14413  [{'branch_code': '', 'direction_headsign': 'UC...
# 1       BBB:69580  [{'branch_code': '', 'direction_headsign': 'UC...
#
#   mode_name  real_time_route_id route_color             route_long_name  \
# 0       Bus                3605      00549e        Wilshire Blvd / UCLA
# 1       Bus                3618      00549e  Culver City Station - UCLA
# 2       Bus                3619      00549e       UCLA - Marina Del Rey
# 0       Bus                3605      00549e        Wilshire Blvd / UCLA
# 1       Bus                3619      00549e       UCLA - Marina Del Rey
#
#            route_network_id route_network_name  route_short_name  \
# ...

# %%
r = Stops['itineraries'].iloc[0]
print(r)
# Out:
# [{'branch_code': '', 'direction_headsign': 'UCLA', 'direction_id': 0, 'headsign': 'UCLA', 'merged_headsign': 'UCLA', 'schedule_items': [{'departure_time': 1684469160, 'is_cancelled': False, 'is_real_time': False, 'rt_trip_id': '903272', 'scheduled_departure_time': 1684469160, 'trip_search_key': 'BBB:42200741:9:2:0', 'wheelchair_accessible': 1}, {'departure_time': 1684555560, 'is_cancelled': False, 'is_real_time': False, 'rt_trip_id': '903272', 'scheduled_departure_time': 1684555560, 'trip_search_key': 'BBB:42200741:9:3:0', 'wheelchair_accessible': 1}, {'departure_time': 1684601100, 'is_cancelled': False, 'is_real_time': False, 'rt_trip_id': '903136', 'scheduled_departure_time': 1684601100, 'trip_search_key': 'BBB:42200741:9:4:0', 'wheelchair_accessible': 1}]}]

# %%
r = Stops['itineraries'].iloc[0]
d = json_normalize(r)
#d = json.loads(r)
print(d)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[17], line 2
#       1 r = Stops['itineraries'].iloc[0]
# ----> 2 d = json_normalize(r)
#       3 #d = json.loads(r)
#       4 print(d)
#
# File ~\UP_anaconda3\lib\site-packages\pandas\io\json\_normalize.py:446, in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     444     data = list(data)
#     445 else:
# --> 446     raise NotImplementedError
#     448 # check to see if a simple recursive function is possible to
#     449 # improve performance (see #15621) but only for cases such
#     450 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     451 if (
#     452     record_path is None
#     453     and meta is None
#    (...)
#     456     and max_level is None
#     457 ):
#
# NotImplementedError:
