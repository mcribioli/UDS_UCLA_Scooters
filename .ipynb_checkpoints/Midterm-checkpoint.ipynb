# %% [markdown]
# ## Midterm Data Exploration

# %% [markdown]
# 1) Getting location stops near UCLA

# %%
import json
import pandas as pd
import requests

# %%
import requests
import json

apiKey = "6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9"

lat = 34.07489658273221
lon = -118.43918554807533

max_distance = 500

endpoint = f"https://external.transitapp.com/v3/public/nearby_stops?lat=34.0748&lon=-118.439&apiKey=6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9"

# Set the headers for the API request
headers = {'apiKey': '6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9'}

# Send the API request
response = requests.get(endpoint, headers=headers)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    stops = response.json()["stops"]
    # Print the list of stops
    print(stops)
else:
    print("Error:", response.status_code)
# Out:
# [{'distance': 108, 'global_stop_id': 'MLA:108716', 'location_type': 0, 'parent_station_global_stop_id': None, 'route_type': 3, 'rt_stop_id': '2452', 'stop_code': '2452', 'stop_lat': 34.07439315750695, 'stop_lon': -118.4379251214577, 'stop_name': 'Hilgard / Wyton', 'wheelchair_boarding': 0}, {'distance': 108, 'global_stop_id': 'MLA:108845', 'location_type': 0, 'parent_station_global_stop_id': None, 'route_type': 3, 'rt_stop_id': '10988', 'stop_code': '10988', 'stop_lat': 34.07418631382978, 'stop_lon': -118.4380780059147, 'stop_name': 'Hilgard / Wyton', 'wheelchair_boarding': 0}, {'distance': 134, 'global_stop_id': 'BBB:6595', 'location_type': 0, 'parent_station_global_stop_id': None, 'route_type': 3, 'rt_stop_id': '1663', 'stop_code': '3097', 'stop_lat': 34.07377262647545, 'stop_lon': -118.438212903965, 'stop_name': 'UCLA Wyton Dr N', 'wheelchair_boarding': 1}, {'distance': 147, 'global_stop_id': 'BBB:6598', 'location_type': 0, 'parent_station_global_stop_id': None, 'route_type': 3, '
# ...

# %%
print(type(stops))
# Out:
# <class 'list'>

# %%
apiKey = "6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9"
requestString = 'https://external.transitapp.com/v3/public/nearby_stops?lat=34.0748&lon=-118.439&apiKey=6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9&json=y'.format(apiKey)
r = requests.get(requestString)
print(r.text)
# Out:
# {
#   "message":"No API key found in request"
# }

# %%
requestString = 'https://external.transitapp.com/v3/public/available_networks'
params = {
      "distance": 500,
      "stop_lat": 45.526168077787894,
      "stop_lon": -73.59506067289408,
      "stop_name": "Luskin ITS",
      "wheelchair_boarding": 0
    }
r = requests.get(requestString, params=params)
print(r.text)
# Out:
# {
#   "message":"No API key found in request"
# }

# %% [markdown]
# 2. Getting Networks Available

# %%
lat = 34.07489658273221
lon = -118.43918554807533

max_distance = 500

endpoint = f"https://external.transitapp.com/v3/public/available_networks?lat=34.0748&lon=-118.439&max_distance=1000&apiKey=6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9"

# Set the headers for the API request
headers = {'apiKey': '6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9'}

# Send the API request
response = requests.get(endpoint, headers=headers)

networks = response.json()["networks"]

print(networks)
# Out:
# [{'network_geometry': {'geometry': {'coordinates': [[[[-118.6879811407415, 34.06337648339716], [-118.6933051171276, 34.08424071518059], [-118.697621854738, 34.14078997787639], [-118.697621854738, 34.14927956184344], [-118.6954634859328, 34.18611572278522], [-118.6911467483224, 34.20554104203188], [-118.6148843838726, 34.39864310446891], [-118.6117187762917, 34.40540599339182], [-118.6097042987402, 34.40943494849482], [-118.6016463885341, 34.42137792255017], [-118.5909984357619, 34.4320258753224], [-118.5781921141845, 34.44080324179681], [-118.3777515978098, 34.5539017671884], [-118.3619235599052, 34.56095243861866], [-118.3448005007174, 34.56541306748271], [-118.3268140940075, 34.5668519800195], [-118.1991825519944, 34.56670808876582], [-118.1799011240014, 34.564837502468], [-118.1616269347842, 34.55980130858924], [-118.1450794406111, 34.55159950712954], [-118.1309780977506, 34.54066377184994], [-118.120042362471, 34.52756966776517], [-117.8079422332415, 34.04495840292626], [-117.800
# ...

# %%
lat = 34.07489658273221
lon = -118.43918554807533

max_distance = 500

endpoint = f"https://external.transitapp.com/v3/public/available_networks?lat=34.0748&lon=-118.439&max_distance=1000&apiKey=6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9"

# Set the headers for the API request
headers = {'apiKey': '6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9'}

# Send the API request
response = requests.get(endpoint, headers=headers)

networks = response.json()["networks"]

print(networks)
# Out:
# [{'network_geometry': {'geometry': {'coordinates': [[[[-118.6879811407415, 34.06337648339716], [-118.6933051171276, 34.08424071518059], [-118.697621854738, 34.14078997787639], [-118.697621854738, 34.14927956184344], [-118.6954634859328, 34.18611572278522], [-118.6911467483224, 34.20554104203188], [-118.6148843838726, 34.39864310446891], [-118.6117187762917, 34.40540599339182], [-118.6097042987402, 34.40943494849482], [-118.6016463885341, 34.42137792255017], [-118.5909984357619, 34.4320258753224], [-118.5781921141845, 34.44080324179681], [-118.3777515978098, 34.5539017671884], [-118.3619235599052, 34.56095243861866], [-118.3448005007174, 34.56541306748271], [-118.3268140940075, 34.5668519800195], [-118.1991825519944, 34.56670808876582], [-118.1799011240014, 34.564837502468], [-118.1616269347842, 34.55980130858924], [-118.1450794406111, 34.55159950712954], [-118.1309780977506, 34.54066377184994], [-118.120042362471, 34.52756966776517], [-117.8079422332415, 34.04495840292626], [-117.800
# ...

# %% [markdown]
# 3. Printing "Placemarks" (THE ONE WE NEED)

# %%
lat = 34.07489658273221
lon = -118.43918554807533

max_distance = 500

endpoint = f"https://external.transitapp.com/v3/map_layers/placemarks?lat=34.0748&lon=-118.439&distance=60&apiKey=6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9"

# Set the headers for the API request
headers = {'apiKey': '6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9'}

# Send the API request
response = requests.get(endpoint, headers=headers)

placemarks = response.json()["placemarks"]

print(placemarks)
# Out:
# [{'title': 'Electric scooter', 'id': '527bab3e-e32d-4476-8952-2b9a7fd15cb2', 'networkName': 'Bird', 'networkId': 676, 'color': '333333', 'textColor': 'FFFFFF', 'latitude': 34.07466888333333, 'longitude': -118.43953705, 'type': 'electric-scooter'}, {'title': 'Electric scooter', 'id': '7cd6157d-83dc-4afd-9600-fb06b67d398a', 'networkName': 'Bird', 'networkId': 676, 'color': '333333', 'textColor': 'FFFFFF', 'latitude': 34.074565883333335, 'longitude': -118.43951416666665, 'type': 'electric-scooter'}, {'title': 'Electric scooter', 'id': '56693da7-f5b9-4ce1-8916-eb1b44f7ac26', 'networkName': 'Bird', 'networkId': 676, 'color': '333333', 'textColor': 'FFFFFF', 'latitude': 34.07452393333333, 'longitude': -118.43952941666666, 'type': 'electric-scooter'}, {'title': 'Electric scooter', 'id': 'b044237c-0102-45ea-ac2f-ce9ef9348295', 'networkName': 'Bird', 'networkId': 676, 'color': '333333', 'textColor': 'FFFFFF', 'latitude': 34.074924466666666, 'longitude': -118.43904876666666, 'type': 'electric-
# ...

# %%
lat = 34.07489658273221
lon = -118.43918554807533

max_distance = 500

Endpoint = f"https://external.transitapp.com/v3/map_layers/placemarks?lat=34.07236868760976&lon=-118.44423503764042&distance=1000&apiKey=6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9"

# Set the headers for the API request
headers = {'apiKey': '6bb0ee84e4c5940b3c0dcd4e5c56247fc4907265dc5d5d37cbe74c6ab82952f9'}

# Send the API request
response = requests.get(Endpoint, headers=headers)

placemarks2 = response.json()["placemarks"]

print(placemarks2)
# Out:
# [{'title': 'Link Scooter', 'id': '808f4162-124f-48cc-a026-f17f61c2dcad', 'networkName': 'LINK', 'networkId': 1319, 'color': 'E5FF01', 'textColor': '07000E', 'latitude': 34.06381, 'longitude': -118.44516, 'type': 'electric-scooter'}, {'title': 'Link Scooter', 'id': '688ad54a-72e5-43d2-ad6f-690fac0c02ae', 'networkName': 'LINK', 'networkId': 1319, 'color': 'E5FF01', 'textColor': '07000E', 'latitude': 34.06957, 'longitude': -118.43843, 'type': 'electric-scooter'}, {'title': 'Link Scooter', 'id': 'b7cc8424-a9d2-4fe7-ba70-859639d39584', 'networkName': 'LINK', 'networkId': 1319, 'color': 'E5FF01', 'textColor': '07000E', 'latitude': 34.06564, 'longitude': -118.44003, 'type': 'electric-scooter'}, {'title': 'Link Scooter', 'id': '4ebce197-e15b-4172-9ffb-5da6bf7ecdea', 'networkName': 'LINK', 'networkId': 1319, 'color': 'E5FF01', 'textColor': '07000E', 'latitude': 34.0662, 'longitude': -118.44729, 'type': 'electric-scooter'}, {'title': 'Link Scooter', 'id': 'e6309ada-1064-41be-9680-90076094f876'
# ...
